# %%
import numpy as np
x1 = np.random.uniform(0, 100, 1000)   # uniform distribution 
x2 = np.random.uniform(0, 100, 1000)
x1.sort()
x2.sort()

error = np.random.normal(0, 2, 1000)  # error belongs to gaussian distribution
y = x1*3 + x2*4 + error

# %%
#x1.reshape(1000,1)
x = np.concatenate((x1.reshape(1000,1), x2.reshape(1000,1)), axis=1)
x.shape
# Out:
# (1000, 2)

# %%
from numpy.linalg import inv       # used to get inverse matrix
xT = x.T
#minW = np.dot(XT * X).I * XT * Y  
a = inv(np.dot(xT, x))
b = np.dot(a, xT)
minW = np.dot(b, y)
print(minW)
# Out:
# [2.95506791 4.04686602]

# %%
from sklearn import linear_model  # linear_model is regarded as a class
regr = linear_model.LinearRegression()
regr.fit(x, y)
print(regr.coef_)
# Out:
# [2.86155101 4.13742416]

# %%
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
X, Y = make_classification(n_samples=1000, n_features=2, n_informative=2,
                           n_redundant=0, n_classes=2)  #binary output
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)
clf = LogisticRegression()
clf.fit(x_train, y_train)

y_predict = clf.predict(x_test)
count = 0
length = y_test.size
for y1, y2 in zip(y_predict, y_test):
    if y1==y2:
        count += 1 
accuracy = count / length
print(accuracy)
print(clf.score(x_test, y_test))
# Out:
# 0.975
# 0.975

# %%
import matplotlib.pyplot as plt
#only consider fisrt two features, why is it like this syntax ?????
fig, ax = plt.subplots()
ax.scatter(X[Y==0,0], X[Y==0,1], c='r', label='True')  
ax.scatter(X[Y==1,0], X[Y==1,1], c='b', label='False')
'''
xx, yy = np.meshgrid[-4:4:.01, -4:4:.01]
grid = np.c_[xx.ravel(), yy.ravel()]
probs = clf.predict_proba(grid)[:, 1].reshape(xx.shape)
ax.contour(xx, yy, probs)
'''
plt.legend()
plt.title('Scatter for two features')
plt.xlabel('feature 0')
plt.ylabel('feature 1')
plt.show()

#plt.scatter(X[:,1], Y)  #X[all][1]
print("done")
# Out:
# done

# %%
plt.scatter(X[:,0], X[:,1], c=Y)

# %%
X2, Y2 = make_classification(n_samples=1000, n_features=5, n_informative=5,
                           n_redundant=0, n_classes=10)  
x_train2, x_test2, y_train2, y_test2 = train_test_split(X2, Y2, test_size=0.2)
clf2 = LogisticRegression()
clf2.fit(x_train2, y_train2)
print(clf2.score(x_test2, y_test2))

fig, ax = plt.subplots()
ax.scatter(X2[Y2==0,0], X2[Y2==0,1], c='r', label='True')  
ax.scatter(X2[Y2==1,0], X2[Y2==1,1], c='b', label='False')
plt.legend()
plt.title('Scatter for fisrt two features')
plt.xlabel('feature 0')
plt.ylabel('feature 1')
plt.show()
# Out:
# 0.365

# %%
a = 0
a == 0,1
# Out:
# (True, 1)
